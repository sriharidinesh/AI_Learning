# %%
def passCheck(num):
    if num >= 40:
        print("Pass")
        return "Pass"
    else:
        print("Fail")
        return "Fail"

# %%
passCheck(40)
# Out:
# Pass
# 'Pass'

# %%
passCheck(39)
# Out:
# Fail
# 'Fail'
