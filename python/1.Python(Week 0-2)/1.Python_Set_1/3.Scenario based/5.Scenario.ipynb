# %%
def reverse():
    str = input("Enter any word or sentence: ")
    print(str)
    print(str[::-1])

# %%
reverse()
# Out:
# Enter any word or sentence:  Hi Hope AI, How are you ?
# Hi Hope AI, How are you ?
# ? uoy era woH ,IA epoH iH
