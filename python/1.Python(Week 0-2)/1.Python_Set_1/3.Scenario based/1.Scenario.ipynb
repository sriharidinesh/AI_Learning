# %%
def EligiblityCheck():
    age = int(input("Enter the Age: "))
    if age >= 18:
        print("Eligible to vote")
    else :
        print("Not Eligible to vote")

# %%
EligiblityCheck()
# Out:
# Enter the Age:  18
# Eligible to vote
