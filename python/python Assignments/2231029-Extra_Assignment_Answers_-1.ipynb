# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
institute_name = input("Enter your institute name? : ")
# Out:
# Enter your institute name? :  HOPE AI

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
school_name = input("Enter your school name: ")
degree = input("Enter your degree: ")
# Out:
# Enter your name:  Dinesh
# Enter your age:  28
# Enter your school name:  GBHSS, Katpadi
# Enter your degree:  M.Tech

# %%
a = 43
b = 34
print(f"a = {a}\nb = {b}\nAdd = {a + b}")
# Out:
# a = 43
# b = 34
# Add = 77

# %%
print(f"a = {a}\nb = {b}\nSub = {a - b}")
# Out:
# a = 43
# b = 34
# Sub = 9

# %%
a= 63; b= 97
print(f"a = {a}\nb = {b}\nMul = {a * b}")
# Out:
# a = 63
# b = 97
# Mul = 6111

# %%
a = 76 ; b= 31
print(f"a = {a}\nb = {b}\nFloat Div = {a / b}")
# Out:
# a = 76
# b = 31
# Float Div = 2.4516129032258065

# %%
print(f"a = {a}\nb = {b}\nFloor Div = {a // b}")
# Out:
# a = 76
# b = 31
# Floor Div = 2

# %%
print(f"a = {a}\nb = {b}\nModulo = {a % b}")
# Out:
# a = 76
# b = 31
# Modulo = 14

# %%
a = 4 ; b = 4
print(f"a = {a}\nb = {b}\nPower = {a ** b}")
# Out:
# a = 4
# b = 4
# Power = 256
