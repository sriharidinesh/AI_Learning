# %%
value = 10
if (value == 10):
    print("Correct")
else:
    print(Incorrect)
# Out:
# Correct

# %%
pssd = input("Enter the Password: ")
if pssd == "HOPE@123":
    print("Your password is correct")
else :
    print("Your password is Incorrect")
# Out:
# Enter the Password:  Hope@123
# Your password is Incorrect

# %%
age = int(input("Enter the Age: "))
if (age < 18):
    print(f"age: {age}\nChildren")
elif (age< 35):
    print(f"age: {age}\nAdult")
elif(age < 59):
    print(f"age: {age}\ncitizen")
else:
    print(f"age: {age}\nsenior Citizen")
# Out:
# Enter the Age:  58
# age: 58
# citizen

# %%
num = int(input("Enter any number: "))
if num >0:
    print("Number is Positive")
else:
    print("Number is Negative")
# Out:
# Enter any number:  1
# Number is Positive

# %%
num = int(input("Enter any number to check whether it is divisble by 5: "))
if num%5 == 0:
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Enter any number to check whether it is divisble by 5:  1254
# Number is not divisible by 5
