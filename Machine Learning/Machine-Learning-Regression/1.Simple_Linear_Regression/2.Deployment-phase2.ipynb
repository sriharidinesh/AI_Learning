# %%
import pickle

# %%
#Loading the file to the variable loaded_model
#predicting the random value using the loaded model and saving it in the result variable
loaded_model = pickle.load(open("finalized_model_linear.sav",'rb'))
result = loaded_model.predict([[16]])
# Out:
# C:\Users\sridi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[176541.5719203]])

# %%
#By preciting with the 0, we can actually get the origin value/intial value/minimum value 
loaded_model.predict([[0]])
# Out:
# C:\Users\sridi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26777.3913412]])
